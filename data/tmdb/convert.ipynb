# %%
import pandas as pd

# %%
df = pd.read_csv('movies_post_2022.tsv', delimiter='\t')

# %%
df
# Out:
#        adult                     backdrop_path                 genre_ids  \
# 0      False  /jkBFGhuJKLH8VurXqVKQ2mxvVYC.jpg                      [37]
# 1      False  /q6y5cjHFiFBEb7ILYrEllOiC4ww.jpg                  [27, 18]
# 2      False  /arT10FrsPdxJOFBrHMrVvoDJCqR.jpg  [16, 35, 878, 10751, 12]
# 3      False  /pBdQ4iorzRV2G38mdS6rzrmUfMA.jpg           [28, 10752, 12]
# 4      False  /94cS0mzODEoNIXFT7nhPcI8V4IJ.jpg                     [878]
# ...      ...                               ...                       ...
# 83712  False                               NaN                      [18]
# 83713  False                               NaN                      [18]
# 83714  False                               NaN                        []
# 83715  False  /cPV6tewTyg9lFrK0ECoRcrQZoIR.jpg                      [35]
# 83716  False                               NaN                        []
#
#             id original_language        original_title  \
# ...

# %%
genres = {28: "Action", 12: "Adventure", 16: "Animation", 35: "Comedy", 80: "Crime", 99: "Documentary", 18: "Drama", 10751: "Family", 14: "Fantasy", 36: "History", 27: "Horror", 10402: "Music", 9648: "Mystery", 10749: "Romance", 878: "Science Fiction", 10770: "TV Movie", 53: "Thriller", 10752: "War", 37: "Western"}

# %%
import re
# reformat date 2023-01-07 to 01/07/2023
df['release_date'] = pd.to_datetime(df['release_date'])
df['release_date'] = df['release_date'].dt.strftime('%m/%d/%Y')

# reformat genres
    # [27, 18] -> [Horror, Drama]
def replace_genre_ids(text, genres):
    for g_id, genre_name in genres.items():
        # Pattern to match the genre ID within different contexts (standalone, start, end, middle)
        pattern = r'(?<!\d)' + re.escape(str(g_id)) + r'(?!\d)'
        # Replace the genre ID with its name, preserving the context.
        text = re.sub(pattern, genre_name, text)
    return text
df['genre_ids'] = df['genre_ids'].apply(lambda x: replace_genre_ids(x, genres))

df
# Out:
#        adult                     backdrop_path  \
# 0      False  /jkBFGhuJKLH8VurXqVKQ2mxvVYC.jpg
# 1      False  /q6y5cjHFiFBEb7ILYrEllOiC4ww.jpg
# 2      False  /arT10FrsPdxJOFBrHMrVvoDJCqR.jpg
# 3      False  /pBdQ4iorzRV2G38mdS6rzrmUfMA.jpg
# 4      False  /94cS0mzODEoNIXFT7nhPcI8V4IJ.jpg
# ...      ...                               ...
# 83712  False                               NaN
# 83713  False                               NaN
# 83714  False                               NaN
# 83715  False  /cPV6tewTyg9lFrK0ECoRcrQZoIR.jpg
# 83716  False                               NaN
#
#                                                genre_ids       id  \
# 0                                              [Western]  1079394
# 1                                        [Horror, Drama]   880100
# 2      [Animation, Comedy, Science Fiction, Family, A...  1078012
# 3                               [Action, War, Adventure]   840326
# ...

# %%
df.to_csv('movies_post_2022_formatted.tsv', sep='\t', index=False)
